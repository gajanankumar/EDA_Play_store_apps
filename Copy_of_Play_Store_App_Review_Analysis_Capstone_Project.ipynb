# %% [markdown]
# <a href="https://colab.research.google.com/github/gajanankumar/EDA_Play_store_apps/blob/play_store_apps/Copy_of_Play_Store_App_Review_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %% [markdown]
# # **Play Store data.csv**: Contains all the details of the applications on Google Play store. There are 13 features that describe a given app.
# # **User Reviews.csv:** Contains 100 reviews for each  android app, most helpful first. The text in each review has been pre-processed and attributed with three new features: Sentiment (Positive, Negative or Neutral), Sentiment Polarity and Sentiment Subjectivity.

# %% [markdown]
# **EDA involves generating summary statistics for numerical data in the dataset and creating various graphical representations to understand the data better and make it more attractive and easy to understand.**
#
# **The following are the various steps involved in the EDA process:**
#
# **Problem Statement** - We shall brainstorm and understand the given data set. We shall study the features present in it and try to do a philosophical analysis about their meaning and importance for this problem.
#
# **Hypothesis** - Upon studying the features present in the data set, we shall develop some basic hypothesis on which we can work and analyze with the data to look for the varied results which we can get out of it.
#
# **Univariate Analysis** - It is the simplest form of analyzing the data. In this we would initially pick up a single feature and study it in and out. It doesn't deal with any sort of co-relation and it's major purpose is to describe. It takes data, summarizes that data and finds patterns in the data.
#
# **Bivariate Analysis** - This analysis is related to cause and the relationship between the two attributes. We will try to understand the dependency of attributes on each other.
#
# **Multivariate Analysis** - This is done when more than two variables have to be analyzed simultaneously.We'll try to understand how the dependent variable and independent variables relate.
#
# **Data Cleaning** - We shall clean the dataset and handle the missing data, outliers and categorical variables.
#
# **Testing Hypothesis** - We shall check if our data meets the assumptions required by most of the multivariate techniques.

# %% [markdown]
# # **Problem statement**
#
# **Explore and analyze the data to discover key factors responsible for app engagement and success.**

# %% [markdown]
# # **Import Libraries**

# %%
# import libraries for analysys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

# %%
# mounting drive to access data
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# # **Data Gathering**

# %%
df = pd.read_csv('/content/drive/MyDrive/almbetter_data/geda_dset/Play Store Data.csv')

# %% [markdown]
# # **Gathered Data basic Information**

# %%
# getting list of column names
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# getting shape of dataframe
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# **Play Store DataFrame has 10841 rows and 13 columns. The 13 columns are identified as below:**
#
# **App**- It tells us about the name of the application.
#
# **Category**- It gives the category to the app.
#
# **Rating**- It contains the average rating the respective app received from its users.
#
# **Reviews**- It tells us about the total number of users who have given a review for the application.
#
# **Size** - It tells us about the size being occupied the application on the mobile phone.
#
# **Installs** - It tells us about the total number of installs/downloads for an application.
#
# **Type** - It tells whether an app is free to use or paid.
#
# **Price** - It gives the price payable to install the app. For free type apps, the price is zero.
#
# **Content Rating** - It states whether or not an app is suitable for all age groups or not.
#
# **Genres** - It tells us about the various other categories to which an application can belong.
#
# **Last Updated** - It tells us about the when the application was updated.
#
# **Current Ver** - It tells us about the current version of the application.
#
# **Android Ver** - It tells us about the android version which can support the application on its platform.

# %%
# getting summary for dataframe including number of index, number of columns, data type,non null count in a dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# getting first 5 rows from dataframe
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#getting last 5 records from dataframe
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
# checking number of not a number values in a dataframe columns
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
#checking duplicate recoreds in dataframe
df.duplicated().sum()
# Out:
# 483

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df.groupby('App').get_group('Box')
# Out:
#      App  Category  Rating Reviews                Size     Installs  Type  \
# 204  Box  BUSINESS     4.2  159872  Varies with device  10,000,000+  Free
# 236  Box  BUSINESS     4.2  159872  Varies with device  10,000,000+  Free
# 265  Box  BUSINESS     4.2  159872  Varies with device  10,000,000+  Free
#
#     Price Content Rating    Genres   Last Updated         Current Ver  \
# 204     0       Everyone  Business  July 31, 2018  Varies with device
# 236     0       Everyone  Business  July 31, 2018  Varies with device
# 265     0       Everyone  Business  July 31, 2018  Varies with device
#
#             Android Ver
# 204  Varies with device
# 236  Varies with device
# 265  Varies with device

# %%
df.groupby('App').get_group('ZOOM Cloud Meetings')
# Out:
#                      App  Category  Rating Reviews Size     Installs  Type  \
# 213  ZOOM Cloud Meetings  BUSINESS     4.4   31614  37M  10,000,000+  Free
# 256  ZOOM Cloud Meetings  BUSINESS     4.4   31614  37M  10,000,000+  Free
#
#     Price Content Rating    Genres   Last Updated     Current Ver Android Ver
# 213     0       Everyone  Business  July 20, 2018  4.1.28165.0716  4.0 and up
# 256     0       Everyone  Business  July 20, 2018  4.1.28165.0716  4.0 and up

# %%
df.groupby('App').get_group('AAFP')
# Out:
#         App Category  Rating Reviews Size Installs  Type Price Content Rating  \
# 2515   AAFP  MEDICAL     3.8      63  24M  10,000+  Free     0       Everyone
# 10768  AAFP  MEDICAL     3.8      63  24M  10,000+  Free     0       Everyone
#
#         Genres   Last Updated Current Ver Android Ver
# 2515   Medical  June 22, 2018       2.3.1  5.0 and up
# 10768  Medical  June 22, 2018       2.3.1  5.0 and up

# %% [markdown]
# **As per observation duplicate records are found in Dataframe, so need drop duplicate records from datafram**e

# %%
df.drop_duplicates(subset = 'App', inplace = True)
df.shape
# Out:
# (9660, 13)

# %%
df.groupby('App').get_group('AAFP')
# Out:
#        App Category  Rating Reviews Size Installs  Type Price Content Rating  \
# 2515  AAFP  MEDICAL     3.8      63  24M  10,000+  Free     0       Everyone
#
#        Genres   Last Updated Current Ver Android Ver
# 2515  Medical  June 22, 2018       2.3.1  5.0 and up

# %% [markdown]
# # **Feature wise data preprocessing in order to get cleaned data**

# %% [markdown]
# # **Univariate Analysis**

# %% [markdown]
# # **1. App**

# %%
# getting first 5 records of app name
df['App'].head()
# Out:
# 0       Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                  Coloring book moana
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                Sketch - Draw & Paint
# 4                Pixel Draw - Number Art Coloring Book
# Name: App, dtype: object

# %% [markdown]
# **Checking Missing values**

# %%
# checking missing values
df['App'].isna().sum()
# Out:
# 0

# %%
#number of unique apps available in dataset
df['App'].nunique()
# Out:
# 9660

# %%
list(df['App'].unique())[:5]
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook',
#  'Coloring book moana',
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#  'Sketch - Draw & Paint',
#  'Pixel Draw - Number Art Coloring Book']

# %%
# value counts of each app
df['App'].value_counts()
# Out:
# Photo Editor & Candy Camera & Grid & ScrapBook    1
# CK Pharmacies                                     1
# CK Call NEW                                       1
# Ck Coif                                           1
# CONTRACT KILLER: ZOMBIES                          1
#                                                  ..
# Bike Race Free - Top Motorcycle Racing Games      1
# Dance School Stories - Dance Dreams Come True     1
# 3D Bowling                                        1
# Mind Games Pro                                    1
# iHoroscope - 2018 Daily Horoscope & Astrology     1
# Name: App, Length: 9660, dtype: int64

# %%
# checking duplicate values in app column
df[df['App']=='ROBLOX']
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
#
#        Current Ver Android Ver
# 1653  2.347.225742  4.1 and up

# %% [markdown]
# # **2. Category**

# %%
# getting first 5 records of app category
df['Category'].head()
# Out:
# 0    ART_AND_DESIGN
# 1    ART_AND_DESIGN
# 2    ART_AND_DESIGN
# 3    ART_AND_DESIGN
# 4    ART_AND_DESIGN
# Name: Category, dtype: object

# %%
#getting no of unique categories
df['Category'].nunique()
# Out:
# 34

# %%
#getting unique app categories
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
#getting app categories missing values
df['Category'].isna().sum()
# Out:
# 0

# %%
# getting app categories value counts dictionary
df['Category'].value_counts().to_dict()
# Out:
# {'FAMILY': 1832,
#  'GAME': 959,
#  'TOOLS': 827,
#  'BUSINESS': 420,
#  'MEDICAL': 395,
#  'PERSONALIZATION': 376,
#  'PRODUCTIVITY': 374,
#  'LIFESTYLE': 369,
#  'FINANCE': 345,
#  'SPORTS': 325,
#  'COMMUNICATION': 315,
#  'HEALTH_AND_FITNESS': 288,
#  'PHOTOGRAPHY': 281,
#  'NEWS_AND_MAGAZINES': 254,
#  'SOCIAL': 239,
#  'BOOKS_AND_REFERENCE': 222,
#  'TRAVEL_AND_LOCAL': 219,
#  'SHOPPING': 202,
#  'DATING': 171,
#  'VIDEO_PLAYERS': 163,
#  'MAPS_AND_NAVIGATION': 131,
#  'EDUCATION': 119,
#  'FOOD_AND_DRINK': 112,
#  'ENTERTAINMENT': 102,
#  'AUTO_AND_VEHICLES': 85,
#  'LIBRARIES_AND_DEMO': 84,
#  'WEATHER': 79,
#  'HOUSE_AND_HOME': 74,
#  'ART_AND_DESIGN': 64,
#  'EVENTS': 64,
#  'PARENTING': 60,
#  'COMICS': 56,
#  'BEAUTY': 53,
#  '1.9': 1}

# %% [markdown]
# # **Here last catogory is '1.9'. this is not correct app cotagory as per observation need to clean this to NaN**

# %%
# to get record of app ctegory '1.9'.
df[df['Category']=='1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               19.0
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %%
# to shift record to right side by 1 here used shift method
df.loc[10472] = df.loc[10472].shift()

# %%
df.loc[10472]
# Out:
# App                                                   NaN
# Category          Life Made WI-Fi Touchscreen Photo Frame
# Rating                                                1.9
# Reviews                                              19.0
# Size                                                 3.0M
# Installs                                           1,000+
# Type                                                 Free
# Price                                                   0
# Content Rating                                   Everyone
# Genres                                                NaN
# Last Updated                            February 11, 2018
# Current Ver                                        1.0.19
# Android Ver                                    4.0 and up
# Name: 10472, dtype: object

# %%
# here there is need to swap records of app and category value for index 10472
df.loc[10472,'App'] = df.loc[10472,'Category']
df.loc[10472,'Category'] = np.nan
df.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              NaN
# Rating                                                1.9
# Reviews                                              19.0
# Size                                                 3.0M
# Installs                                           1,000+
# Type                                                 Free
# Price                                                   0
# Content Rating                                   Everyone
# Genres                                                NaN
# Last Updated                            February 11, 2018
# Current Ver                                        1.0.19
# Android Ver                                    4.0 and up
# Name: 10472, dtype: object

# %%
# bar plot of category wise number of apps
plt.figure(figsize = (20,10))
#df['Category'].value_counts().plot(kind='bar')
sns.countplot(x='Category', data=df)
plt.title('App category value counts')
plt.xticks(rotation=90)
plt.ylabel(' Category wise Total number of apps')
plt.xlabel(' App categories')
# Out:
# Text(0.5, 0, ' App categories')

# %% [markdown]
# From above plot we conclude that most of the apps in the play store are from the 'Family' categories, and after that'Game' and also 'Tools.

# %% [markdown]
# # **3. Rating**

# %%
df['Rating'].head()
# Out:
# 0    4.1
# 1    3.9
# 2    4.7
# 3    4.5
# 4    4.3
# Name: Rating, dtype: object

# %%
#getting unique rating count
df['Rating'].nunique()
# Out:
# 40

# %%
#getting rating unique values
df['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4.0, nan, 4.8,
#        4.9, 3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5.0, 2.6, 3.0, 1.9, 2.5, 2.8,
#        2.7, 1.0, 2.9, 2.3, 2.2, 1.7, 2.0, 1.8, 2.4, 1.6, 2.1, 1.4, 1.5,
#        1.2, '1.9'], dtype=object)

# %%
# caculating median of ratings
median_rating = df[~df['Rating'].isnull()]['Rating'].median()

median_rating
# Out:
# 4.3

# %%
#calculating mean if ratings
mean_rating = df[~df['Rating'].isnull()]['Rating'].astype(float).mean()

mean_rating
# Out:
# 4.172965719165549

# %%
#checking null and nan values
df['Rating'].isna().sum()
# Out:
# 1463

# %%
#filling nan values with median central tendancy
df['Rating']= df['Rating'].fillna(median_rating).astype(float)

# %%
# checking data type of rating feature
df['Rating'].dtype
# Out:
# dtype('float64')

# %%
#checking statistical summary of ratings features
df['Rating'].describe()
# Out:
# count    9660.000000
# mean        4.192205
# std         0.496919
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %% [markdown]
# # **Here data type of rating is object. as rating should be in float as per data**

# %%
# histogram plot of ratings to check distribution
plt.figure(figsize=(10,5))
plt.hist(df['Rating'], color='orange')
plt.xlabel('Rating')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Distribution and Box plot of ratings to check outliers
fig, ax = plt.subplots(2,1, figsize=(12,7))
sns.distplot(df['Rating'],color='orange',ax=ax[0])
sns.boxplot(x='Rating',data=df, ax=ax[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * The mean of the average ratings ( the NaN values replacing with median) comes to be 4.2.
#
# * The median of the entries (the NaN values replacing with median) in the 'Rating' column comes to be 4.3. From this we can say that 50% of the apps have an average rating of above 4.3, and the rest below 4.3.
#
# * From the distplot visualizations, it is clear that the ratings are left skewed.
#
# * We know that if the variable is skewed, the mean is biased by the values at the far end of the distribution. Therefore, the median is a better representation of the majority of the values in the variable.
#
# * Hence we imputed the NaN values in the Rating column with its median.

# %% [markdown]
# # **4. Reviews**

# %%
#getting first 5 records of Reviews feature
df['Reviews'].head()
# Out:
# 0       159
# 1       967
# 2     87510
# 3    215644
# 4       967
# Name: Reviews, dtype: object

# %%
# getting last 5 record of Reviews features
df['Reviews'].tail()
# Out:
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, dtype: object

# %%
#getting unique review count
df['Reviews'].nunique()
# Out:
# 5331

# %%
#getting reviews unique values
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
#checking missing values
df['Reviews'].isna().sum()
# Out:
# 0

# %%
#converting dtype of reviews from object to int
df['Reviews'] = df['Reviews'].replace("0.0",0)
df['Reviews'] = df['Reviews'].replace("3.0M",3000000)
df['Reviews'] = df['Reviews'].astype(int)
df['Reviews'].dtype
# Out:
# dtype('int64')

# %%
#getting statistical summary of Reviews column
df['Reviews'].describe()
# Out:
# count    9.660000e+03
# mean     2.165701e+05
# std      1.831226e+06
# min      0.000000e+00
# 25%      2.500000e+01
# 50%      9.670000e+02
# 75%      2.939400e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
#box plot for outliers in Reviews
fig, ax = plt.subplots(2,1, figsize=(12,7))
sns.boxplot(x='Reviews',data=df, ax=ax[0])

# %%
# line graph for checking relationship between rating and reviews
rating_df = df.groupby('Rating').sum().reset_index()

#fig, axes = plt.subplots(1, 4, figsize=(14, 4))
plt.figure(figsize = (12,8))
plt.plot(rating_df['Rating'], rating_df['Reviews'], 'r')
plt.xlabel('Rating')
plt.ylabel('Reviews')
plt.title('Reviews Per Rating')
# Out:
# Text(0.5, 1.0, 'Reviews Per Rating')

# %% [markdown]
# From above plot we can conclude that for  app ratings between 4.0 to 5.0 there are maximum reviews by user.

# %%
#getting all records of reviews numbers 3
df[df['Reviews']==3]
# Out:
#                                         App             Category  Rating  \
# 610                       Random Video Chat               DATING     4.3
# 611                             MouseMingle               DATING     2.7
# 613    Random Video Chat App With Strangers               DATING     4.3
# 626     Fishing Brain & Boating Maps Marine               DATING     4.3
# 654         Speeding Joyride & Car Meet App               DATING     5.0
# ...                                     ...                  ...     ...
# 10621           Florida Beach Wallpapers HD     TRAVEL_AND_LOCAL     5.0
# 10631                   ORLANDO FLORIDA MAP     TRAVEL_AND_LOCAL     4.3
# 10737                             FP Legacy  MAPS_AND_NAVIGATION     4.0
# 10805                         Scoreboard FR            LIFESTYLE     4.3
# 10838                Parkinson Exercices FR              MEDICAL     4.3
#
#        Reviews  Size Installs  Type Price Content Rating             Genres  \
# ...

# %%
#getting statistcal information of Reviews feature
df['Reviews'].describe()
# Out:
# count    9.660000e+03
# mean     2.165701e+05
# std      1.831226e+06
# min      0.000000e+00
# 25%      2.500000e+01
# 50%      9.670000e+02
# 75%      2.939400e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %% [markdown]
# # **5. Size**

# %%
#getting unique size count
df['Size'].nunique()
# Out:
# 461

# %%
#getting unique size values
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
# Defining a function to convert all the entries in KB to MB and then converting them to float datatype.

def convert_size(size):
  '''
  This function converts all the valid entries in KB to MB and returns the result in float datatype.
  '''
  try:
    if 'M' in size:
      return float(size[:-1])
    elif 'k' in size:
      return round(float(size[:-1])/1024, 3)
    else:
      return size
  except:
    return size

# %%
# The kb_to_mb funtion applied to the size column

df['Size'] = df['Size'].apply(lambda x: convert_size(x))
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159  19.0      10,000+  Free     0       Everyone
# 1      967  14.0     500,000+  Free     0       Everyone
# 2    87510   8.7   5,000,000+  Free     0       Everyone
# 3   215644  25.0  50,000,000+  Free     0           Teen
# 4      967   2.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#getting last unique value of size
df['Size'].unique()[-1]
# Out:
# 0.604

# %%
#replacing "Varies with device" with NaN
df['Size']=df['Size'].replace("Varies with device",np.nan)

# %%
#converted Size dtype from object to float
df['Size']=df['Size'].astype(float)
df['Size'].dtype
# Out:
# dtype('float64')

# %%
#checking value counts of size
df['Size'].value_counts()
# Out:
# 11.000    182
# 12.000    181
# 14.000    177
# 13.000    177
# 15.000    163
#          ...
# 0.420       1
# 0.419       1
# 0.195       1
# 0.449       1
# 0.604       1
# Name: Size, Length: 457, dtype: int64

# %%
# getting statistics of size feature
df['Size'].describe()
# Out:
# count    8433.000000
# mean       20.392834
# std        21.827426
# min         0.008000
# 25%         4.600000
# 50%        12.000000
# 75%        28.000000
# max       100.000000
# Name: Size, dtype: float64

# %%
#cheking null values in size column
df['Size'].isna().sum()
# Out:
# 1227

# %%
#getting median size of size features
median_size = df[~df['Size'].isnull()]['Size'].median()
median_size
# Out:
# 12.0

# %%
#filling null values with median size value
df['Size']= df['Size'].fillna(median_size).astype(float)

# %%
#Distrubution and box pot for size feature
fig, ax = plt.subplots(2,1, figsize=(12,7))
sns.distplot(df.Size, color='purple', ax=ax[0])
sns.boxplot(x='Size',data=df, ax=ax[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * It is clear from the visualizations that the data in the Size column is skewed towards the right.
#
# * Also, we see that a vast majority of the entries in this column are of the value Varies with device, replacing this with any central tendency value (mean or median) may give incorrect visualizations and results. Hence these values are left as it is.
#
# * We have successfully converted all the valid entries in the Size column to a single unit of measure (MB) and the datatype from string to float.

# %% [markdown]
# # **6. Installs**

# %%
#getting unique values Installs count
df['Installs'].nunique()
# Out:
# 21

# %%
#getting unique Installs values
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %% [markdown]
# # **Here dtype is object, so need to conver in float and + with ""**

# %%
# repacing "," and "+" in installs values and converting datype
df['Installs'] = df['Installs'].str.replace(",","")
df['Installs'] = df['Installs'].str.replace("+","")
df['Installs'] = df.Installs.replace("Free",np.nan)
df['Installs'] = df['Installs'].astype(float)
df['Installs'].dtype
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# dtype('float64')

# %%
# checking statics of installs features
df['Installs'].describe()
# Out:
# count    9.660000e+03
# mean     7.776702e+06
# std      5.375555e+07
# min      0.000000e+00
# 25%      1.000000e+03
# 50%      1.000000e+05
# 75%      1.000000e+06
# max      1.000000e+09
# Name: Installs, dtype: float64

# %%
df['Installs'].unique()
# Out:
# array([1.e+04, 5.e+05, 5.e+06, 5.e+07, 1.e+05, 5.e+04, 1.e+06, 1.e+07,
#        5.e+03, 1.e+08, 1.e+09, 1.e+03, 5.e+08, 5.e+01, 1.e+02, 5.e+02,
#        1.e+01, 1.e+00, 5.e+00, 0.e+00])

# %% [markdown]
# The resultant values in the Installs column are of the integer datatype, and it represents the least number of times a particular app has been installed.
#
# **Installs** = 0 indicates that that particular app has not been installed by anyone yet.
# Installs = 1 indicates that the particular app has been installed by atleast one user.
# **Installs** = 1000000 indicates that the particular app has been installed by atleast one million users. So on and so forth.
# We have successfully converted the datatype of values in the Installs column from string to int.

# %%
# get the number of installs for each category
categories = df.groupby('Category')
category_installs_sum_df = categories[['Installs']].sum()
category_installs_sum_df = category_installs_sum_df.reset_index()  # to convert groupby object into dataframe

plt.figure(figsize=(15, 8))
sns.barplot(x='Category', y='Installs', data=category_installs_sum_df)
plt.xticks(rotation=90)
plt.ylabel('Installs (e+10)')
plt.title('Number of Installs For Each Category')
plt.show()

# %% [markdown]
# From above plot we conclude that Game category has maximum number of installations.

# %%
category_installs_sum_df = categories[['Installs']].sum()
category_installs_sum_df
# Out:
#                          Installs
# Category
# ART_AND_DESIGN       1.143381e+08
# AUTO_AND_VEHICLES    5.313021e+07
# BEAUTY               2.719705e+07
# BOOKS_AND_REFERENCE  1.665970e+09
# BUSINESS             6.971649e+08
# COMICS               4.498115e+07
# COMMUNICATION        1.103828e+10
# DATING               1.409261e+08
# EDUCATION            3.529520e+08
# ENTERTAINMENT        2.113660e+09
# EVENTS               1.597316e+07
# FAMILY               4.427942e+09
# FINANCE              4.553487e+08
# FOOD_AND_DRINK       2.117988e+08
# GAME                 1.387892e+10
# HEALTH_AND_FITNESS   1.144023e+09
# HOUSE_AND_HOME       9.721246e+07
# LIBRARIES_AND_DEMO   5.299591e+07
# LIFESTYLE            5.038235e+08
# MAPS_AND_NAVIGATION  5.032819e+08
# MEDICAL              3.819318e+07
# NEWS_AND_MAGAZINES   2.369218e+09
# PARENTING            3.152111e+07
# PERSONALIZATION      1.532495e+09
# PHOTOGRAPHY          4.649148e+09
# PRODUCTIVITY         5.793091e+09
# ...

# %% [markdown]
# # **7. Type**

# %%
#getting number of unique values in Type features
df['Type'].nunique()
# Out:
# 2

# %%
#getting unique value in type feature
df['Type'].unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
#to fill null values by mode
df['Type'].fillna('Free',inplace=True)

# %%
# plotting piechart to show percentage of free and paid apps
import matplotlib
counts = list(df['Type'].value_counts())
labels = 'Free', 'Paid',
matplotlib.rcParams['font.size'] = 25
matplotlib.rcParams['figure.figsize'] = (12, 17)
plt.pie(counts, labels=labels,shadow=True, autopct="%.2f%%")
plt.title('Percentage of Free and Paid apps', fontsize=20)
plt.axis('off')
plt.legend(bbox_to_anchor=(0.9, 0, 0.5, 1))
plt.show()
plt.savefig('free_paid_apps.jpg')

# %% [markdown]
# # **8. Price**

# %%
#getting unique Price values
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
#getting unique values count of price 
df['Price'].nunique()
# Out:
# 92

# %% [markdown]
# # **converting dtype object to float**

# %%
#replacing "$" with ""
df['Price'] = df['Price'].str.replace("$","")
df['Price'].dtype
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# dtype('O')

# %%
# converting data type of price to float
df['Price']=df['Price'].astype(float)

# %%
#getting unique values of price featur
df['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %% [markdown]
# # **9. Last Updated**

# %%
#getting unique Last updated values
df['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
#getting unique values count of Last updated
df['Last Updated'].nunique()
# Out:
# 1377

# %%
#checking last updated column as series
df['Last Updated']
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 9660, dtype: object

# %%
#converting data type of last updated column to datetime type and adding month and year column to dataframe
#df['Last Updated'] = pd.to_datetime(df['Last Updated'])
#df["Update year"] = df["Last Updated"].apply(lambda x: x.strptime('%Y')).astype('int64')
df['Year'] = pd.DatetimeIndex(df['Last Updated']).year 
df['Month'] = pd.DatetimeIndex(df['Last Updated']).month
df['Last Updated'] = pd.to_datetime(df['Last Updated'])
df['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 9660, dtype: datetime64[ns]

# %%
#plotting last updated and reviews plot
last_up_df = df.groupby('Last Updated').sum().reset_index()

#fig, axes = plt.subplots(1, 4, figsize=(14, 4))
plt.figure(figsize = (12,8))
plt.plot(last_up_df['Last Updated'], last_up_df['Reviews'], 'g')
plt.xlabel('Last Updated')
plt.ylabel('Reviews')
plt.title('Reviews Per last update')
# Out:
# Text(0.5, 1.0, 'Reviews Per last update')

# %% [markdown]
# From above plot we conclude that last updated apps has maximum reviews.

# %% [markdown]
# # **10. Content Rating**

# %%
#getting unique vaues of content ratings
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
#getting number of unique values
df['Content Rating'].nunique()
# Out:
# 6

# %%
#getting value counts of unique values
df['Content Rating'].value_counts()
# Out:
# Everyone           7904
# Teen               1036
# Mature 17+          393
# Everyone 10+        322
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
# plotting bar plot of content ratings
plt.figure(figsize=(16,11))
sns.countplot(data=df, x='Content Rating')
plt.xticks(rotation=70)
plt.title('Content Rating',color = 'blue',fontsize=15)
plt.show()

# %% [markdown]
# From above plot we conclude that contents for Everyone has maximum rating count.

# %% [markdown]
# # **11. Genres**

# %%
#getting unique values of genre feature
df['Genres'].unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %%
#getting number of unique genres
df['Genres'].nunique()
# Out:
# 119

# %% [markdown]
# # **12. Current Ver**

# %%
#getting number of unique values of current version apps
df['Current Ver'].nunique()
# Out:
# 2817

# %%
#getting unique values of current version pf apps
df['Current Ver'].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.0.612928', '0.3.4', '2.0.148.0'],
#       dtype=object)

# %%
#extracting all values of current version equal to '1.0.0'
df[df['Current Ver']=='1.0.0']
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 23                                Mcqueen Coloring pages       ART_AND_DESIGN
# 44           Popsicle Sticks and Similar DIY Craft Ideas       ART_AND_DESIGN
# 120                 Beauty Tips - Beauty Tips in Sinhala               BEAUTY
# 526                       NoBuffDating - Free Dating App               DATING
# ...                                                  ...                  ...
# 10460                            Wi-Fi Rabbit Unlock Key                TOOLS
# 10702                 Theme fo Oppo A30 Wallpaper & Icon             BUSINESS
# 10706  Neon Blue Gaming Wallpaper&Theme fo Lenovo K8 ...             BUSINESS
# 10761                             Greek Bible FP (Audio)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
#
# ...

# %% [markdown]
# # **13. Android Ver**

# %%
# getting number of unique values of android version
df['Android Ver'].nunique()
# Out:
# 33

# %%
#getting unique values of android version
df['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
#replacing 'Varies with device' with nan
df['Android Ver'].replace({'Varies with device':np.nan},inplace=True)

# %%
df['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up', nan,
#        '2.2 and up', '5.0 and up', '6.0 and up', '1.6 and up',
#        '1.5 and up', '2.1 and up', '7.0 and up', '5.1 and up',
#        '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up', '3.2 and up',
#        '4.4W and up', '7.1 and up', '7.0 - 7.1.1', '8.0 and up',
#        '5.0 - 8.0', '3.1 and up', '2.0.1 and up', '4.1 - 7.1.1',
#        '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1', '5.0 - 7.1.1'],
#       dtype=object)

# %%
df['Android Ver']=df['Android Ver'].str.replace('  and up','')

# %%
df['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up', nan,
#        '2.2 and up', '5.0 and up', '6.0 and up', '1.6 and up',
#        '1.5 and up', '2.1 and up', '7.0 and up', '5.1 and up',
#        '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up', '3.2 and up',
#        '4.4W and up', '7.1 and up', '7.0 - 7.1.1', '8.0 and up',
#        '5.0 - 8.0', '3.1 and up', '2.0.1 and up', '4.1 - 7.1.1',
#        '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1', '5.0 - 7.1.1'],
#       dtype=object)

# %% [markdown]
# # **Exploratory Data Analysys**

# %%
#getting statistics of Dataframe of play store apps
df.describe()
# Out:
#             Rating       Reviews         Size      Installs        Price  \
# count  9660.000000  9.660000e+03  9660.000000  9.660000e+03  9660.000000
# mean      4.192205  2.165701e+05    19.326787  7.776702e+06     1.099185
# std       0.496919  1.831226e+06    20.584592  5.375555e+07    16.851283
# min       1.000000  0.000000e+00     0.008000  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01     5.300000  1.000000e+03     0.000000
# 50%       4.300000  9.670000e+02    12.000000  1.000000e+05     0.000000
# 75%       4.500000  2.939400e+04    25.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09   400.000000
#
#               Year        Month
# count  9660.000000  9660.000000
# mean   2017.345756     6.363561
# std       1.137561     2.659843
# min    2010.000000     1.000000
# 25%    2017.000000     5.000000
# 50%    2018.000000     7.000000
# 75%    2018.000000     8.000000
# max    2018.000000    12.000000

# %% [markdown]
# **Bivariate Analysis** Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters. It also helps to form some simple classification models by drawing some simple lines or make linear separation in our data-set.
#
# Plot a pairwise plot between all the quantitative variables to look for any evident patterns or relationships between the features

# %%
#getting pairplot of rating, size,reviews,type,price features in order to check relation
Rating = df['Rating']
Size = df['Size']
Installs = df['Installs']
Reviews = df['Reviews']
Type = df['Type']
Price = df['Price']

p = sns.pairplot(pd.DataFrame(list(zip(Rating, Size, np.log(Installs), np.log10(Reviews), Price, Type)), 
                        columns=['Rating','Size', 'Installs', 'Reviews', 'Price','Type']), hue='Type',size=2.5)
p.fig.suptitle("Pairwise Plot - Rating, Size, Installs, Reviews, Price",x=0.5, y=1.0, fontsize=16)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Pairwise Plot - Rating, Size, Installs, Reviews, Price')

# %% [markdown]
# **Insights**
#
# Most of the App are Free.
#
# Most of the Paid Apps have Rating around 4
#
# As the number of installation increases the number of reviews of the particaular app also increases.
#
# From the above plottings, we can conclude that most of the apps with higher rating range of 4.0 - 4.7 are having high amount of reviews, size, and installs.
#
# There is no relationship between price and rating of apps.

# %%
#getting wordcloud to show important features
from wordcloud import WordCloud
plt.subplots(figsize=(8,8))
wordcloud = WordCloud(
                          background_color='white',
                          width=512,
                          height=384
                         ).generate(" ".join(df))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('graph.png')

plt.show()

# %%
#getting heatmap to corelation between fetures
plt.figure(figsize = (20,10))
sns.heatmap(df.corr(), annot= True)
plt.title('Corelation Heatmap for playstore app data', size=20)
# Out:
# Text(0.5, 1.0, 'Corelation Heatmap for playstore app data')

# %% [markdown]
# * There is a strong positive correlation between the Reviews and Installs column. As Higher the number of installs, higher is the user base, and higher are the total number of reviews dropped by the users.
#
# * The Price is slightly negatively correlated with the Rating, Reviews, and Installs. This means that as the prices of the app increases, the average rating, total number of reviews and Installs fall slightly.
#
# * The Rating is slightly positively correlated with the Installs and Reviews column. This indicates that as the the average user rating increases, the app installs and number of reviews also increase.

# %% [markdown]
# # **User Reviews Dataset analysys**

# %%
# reading User reviews data fro users reviews dataset
df_u_reviews=pd.read_csv('/content/drive/MyDrive/almbetter_data/geda_dset/User Reviews.csv')

# %%
#getting first 5 records of user reviews
df_u_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
#getting columns of user review dataframe
df_u_reviews.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
#getting summary information about dataframe including number of rows and columns
df_u_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# ### **Let us check if there is any co-relation in both the dataframes.**

# %%
#merging two dataframes
merged_df = pd.merge(df, df_u_reviews, on='App', how = "inner")

# %%
#getting merged DataFrame
merged_df
# Out:
#                                 App        Category  Rating  Reviews  Size  \
# 0               Coloring book moana  ART_AND_DESIGN     3.9      967  14.0
# 1               Coloring book moana  ART_AND_DESIGN     3.9      967  14.0
# 2               Coloring book moana  ART_AND_DESIGN     3.9      967  14.0
# 3               Coloring book moana  ART_AND_DESIGN     3.9      967  14.0
# 4               Coloring book moana  ART_AND_DESIGN     3.9      967  14.0
# ...                             ...             ...     ...      ...   ...
# 61551  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941  12.0
# 61552  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941  12.0
# 61553  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941  12.0
# 61554  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941  12.0
# 61555  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941  12.0
#
# ...

# %%
#getting merged dataframe columns
merged_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Year', 'Month', 'Translated_Review', 'Sentiment',
#        'Sentiment_Polarity', 'Sentiment_Subjectivity'],
#       dtype='object')

# %%
#getting merged dataframe info
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61556 entries, 0 to 61555
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     61556 non-null  object
#  1   Category                61556 non-null  object
#  2   Rating                  61556 non-null  float64
#  3   Reviews                 61556 non-null  int64
#  4   Size                    61556 non-null  float64
#  5   Installs                61556 non-null  float64
#  6   Type                    61556 non-null  object
#  7   Price                   61556 non-null  float64
#  8   Content Rating          61556 non-null  object
#  9   Genres                  61556 non-null  object
#  10  Last Updated            61556 non-null  datetime64[ns]
#  11  Current Ver             61556 non-null  object
#  12  Android Ver             45690 non-null  object
#  13  Year                    61556 non-null  int64
# ...

# %%
#getting merged dataframe corelaion between features
merged_df.corr()
# Out:
#                           Rating   Reviews      Size  Installs     Price  \
# Rating                  1.000000  0.093589  0.123144  0.005643 -0.077680
# Reviews                 0.093589  1.000000  0.236840  0.441833 -0.021911
# Size                    0.123144  0.236840  1.000000  0.007209  0.043873
# Installs                0.005643  0.441833  0.007209  1.000000 -0.026538
# Price                  -0.077680 -0.021911  0.043873 -0.026538  1.000000
# Year                    0.249034  0.078271  0.149899  0.091598 -0.092249
# Month                   0.048305  0.052295 -0.015112  0.097109  0.062177
# Sentiment_Polarity      0.092889 -0.080007 -0.118371 -0.057825  0.024154
# Sentiment_Subjectivity  0.068716 -0.009265  0.013545 -0.006248  0.003204
#
#                             Year     Month  Sentiment_Polarity  \
# Rating                  0.249034  0.048305            0.092889
# Reviews                 0.078271  0.052295           -0.080007
# ...

# %%
# Heat Map for the merged data frame
plt.figure(figsize = (18,12))
sns.heatmap(merged_df.corr(), annot= True)
plt.title(' Heatmap for merged Dataframe', size=20)
# Out:
# Text(0.5, 1.0, ' Heatmap for merged Dataframe')

# %% [markdown]
# * Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix. In this, to represent more common values or higher activities brighter colors basically reddish colors are used and to represent less common or activity values, darker colors are preferred. Heatmap is also defined by the name of the shading matrix. Heatmaps in Seaborn can be plotted by using the seaborn.heatmap() function.
#
# * weak correlation is represented by balck colour
#
# * strong correlation is represented by white colour
#
# * Here Reviews and installs features are positively correlated.

# %% [markdown]
# # **User Reviews dataset contains 5 columns and 64295 records.**

# %%
#checkin null values in user reviews dataframe
df_u_reviews.isna().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
#checking shape of user reviews dataframe
df_u_reviews.shape
# Out:
# (64295, 5)

# %% [markdown]
# **App**: Contains the name of the app with a its description.
#
# **Translated_Review**: It contains the English translation of the review dropped by the user of the app.
#
# **Sentiment**: It gives the attitude/emotion of the User. It can be ‘Positive’, ‘Negative’, or ‘Neutral’.
#
# **Sentiment_Polarity**: It gives the polarity of the User review. Its range is [-1,1], where 1 means ‘Positive statement’ and -1 means a ‘Negative statement’.
#
# **Sentiment_Subjectivity**: This value gives how close a reviewers opinion is to the opinion of the general public. Its range is [0,1]. Higher the subjectivity, closer is the reviewers opinion to the opinion of the general public, and lower subjectivity indicates the review is more of a factual information.

# %% [markdown]
#  **Here total records are 64295 but in columns Translated_Review', 'Sentiment', 'Sentiment_Polarity','Sentiment_Subjectivity' 26868 missing values found. as per observation nearabout 40% values are missing.**

# %%
#getting info abou reviews dataframe
def Urinfo():
  temp1=pd.DataFrame(index=df_u_reviews.columns)
  temp1["datatype"]=df_u_reviews.dtypes
  temp1["not null values"]=df_u_reviews.count()
  temp1["null value"]=df_u_reviews.isnull().sum()
  temp1["% of the null value"]=df_u_reviews.isnull().mean().round(4)*100
  temp1["unique count"]=df_u_reviews.nunique()
  return temp1
Urinfo()
# Out:
#                        datatype  not null values  null value  \
# App                      object            64295           0
# Translated_Review        object            37427       26868
# Sentiment                object            37432       26863
# Sentiment_Polarity      float64            37432       26863
# Sentiment_Subjectivity  float64            37432       26863
#
#                         % of the null value  unique count
# App                                    0.00          1074
# Translated_Review                     41.79         27994
# Sentiment                             41.78             3
# Sentiment_Polarity                    41.78          5410
# Sentiment_Subjectivity                41.78          4474

# %%
#dropping null vaes from dataframe
df_u_reviews = df_u_reviews.dropna()

# %%
#getting shape after dropping null values
df_u_reviews.shape
# Out:
# (37427, 5)

# %% [markdown]
# # **Column wise data analysys**

# %% [markdown]
# # **1. App**

# %%
#getting first 5 records of apps feture
df_u_reviews['App'].head()
# Out:
# 0    10 Best Foods for You
# 1    10 Best Foods for You
# 3    10 Best Foods for You
# 4    10 Best Foods for You
# 5    10 Best Foods for You
# Name: App, dtype: object

# %%
#getting unique apps
df_u_reviews['App'].unique()
# Out:
# array(['10 Best Foods for You', '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#        '11st', '1800 Contacts - Lens Store',
#        '1LINE – One Line with One Touch',
#        '2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif',
#        '21-Day Meditation Experience',
#        '2Date Dating App, Love and matching',
#        '2GIS: directory & navigator', '2RedBeans',
#        '2ndLine - Second Phone Number',
#        '30 Day Fitness Challenge - Workout at Home',
#        '365Scores - Live Scores', '3D Live Neon Weed Launcher',
#        '4 in a Row', '4K Wallpapers and Ultra HD Backgrounds',
#        '591房屋交易-租屋、中古屋、新建案、實價登錄、別墅透天、公寓套房、捷運、買房賣房行情、房價房貸查詢', '591房屋交易-香港',
#        '7 Cups: Anxiety & Stress Chat', '7 Day Food Journal Challenge',
#        '7 Minute Workout', '7 Weeks - Habit & Goal Tracker',
#        '8 Ball Pool', '850 Sports News Digest',
#        '8fit Workouts & Meal Planner', '95Live -SG#1 Live Streaming App',
#        'A Call From Santa Claus!', 'A Word A Day',
# ...

# %%
#getting number of unique apps
df_u_reviews['App'].nunique()
# Out:
# 865

# %%
#checking null values an app feature
df_u_reviews['App'].isna().sum()
# Out:
# 0

# %% [markdown]
# # **2. Translated_Review**

# %%
#getting first 5 record of translated reviews feature
df_u_reviews['Translated_Review'].head()
# Out:
# 0    I like eat delicious food. That's I'm cooking ...
# 1      This help eating healthy exercise regular basis
# 3           Works great especially going grocery store
# 4                                         Best idea us
# 5                                             Best way
# Name: Translated_Review, dtype: object

# %%
#checking for null values
df_u_reviews['Translated_Review'].isna().sum()
# Out:
# 0

# %%
#getting number of unique values
df_u_reviews['Translated_Review'].nunique()
# Out:
# 27994

# %%
#getting unique values
df_u_reviews['Translated_Review'].value_counts()
# Out:
# Good                                                                                                                                                                                                                                                                                                                 247
# Nice                                                                                                                                                                                                                                                                                                                 173
# Great                                                                                                                                                                                                                                                                                                                131
# ...

# %% [markdown]
# # **3.Sentiment**

# %%
#getting first 5 records of Sentiment feature
df_u_reviews['Sentiment'].head()
# Out:
# 0    Positive
# 1    Positive
# 3    Positive
# 4    Positive
# 5    Positive
# Name: Sentiment, dtype: object

# %%
#getting number of unique values of sentiment feature
df_u_reviews['Sentiment'].nunique()
# Out:
# 3

# %%
#getting unique sentiments
df_u_reviews['Sentiment'].unique()
# Out:
# array(['Positive', 'Neutral', 'Negative'], dtype=object)

# %%
#getting sentiment value counts
df_u_reviews['Sentiment'].value_counts()
# Out:
# Positive    23998
# Negative     8271
# Neutral      5158
# Name: Sentiment, dtype: int64

# %%
#to plot Bar plot of sentiment feature
plt.figure(figsize=(14,9))
#df_u_reviews['Sentiment'].value_counts().plot(kind='bar')
sns.countplot(data=df_u_reviews, x='Sentiment')
plt.xticks(rotation=70)
plt.title('Reviews Sentiment',color = 'blue',fontsize=15)
plt.show()

# %% [markdown]
# # **Q. How many reviews are of positive sentiment?**

# %% [markdown]
# ans - Positive sentiments are 23998

# %% [markdown]
# # **Q. How many reviews are of negative sentiment?**
#
# ans - Negative reviews found are 8271 in numbers

# %% [markdown]
# # **Q. How many reviews are of neutral sentiment?**
# ans-Neutral 5163

# %% [markdown]
# # **4.Sentiment_Polarity**

# %%
#getting first 5 records of Sentiment_Polarity feature
df_u_reviews['Sentiment_Polarity'].head()
# Out:
# 0    1.00
# 1    0.25
# 3    0.40
# 4    1.00
# 5    1.00
# Name: Sentiment_Polarity, dtype: float64

# %%
#getting number of unique vaues of Sentiment_Polarity
df_u_reviews['Sentiment_Polarity'].nunique()
# Out:
# 5410

# %%
#getting unique vaues of Sentiment_Polarity
df_u_reviews['Sentiment_Polarity'].unique()
# Out:
# array([ 1.        ,  0.25      ,  0.4       , ..., -0.52857143,
#        -0.37777778,  0.17333333])

# %%
# getting value counts of sentimet polarity
df_u_reviews['Sentiment_Polarity'].value_counts()
# Out:
#  0.000000    5158
#  0.500000    1524
#  0.700000     991
#  1.000000     959
#  0.800000     639
#              ...
# -0.072024       1
#  0.452000       1
#  0.076190       1
# -0.067256       1
#  0.173333       1
# Name: Sentiment_Polarity, Length: 5410, dtype: int64

# %%
#getting statistics of sentiment polarity
df_u_reviews['Sentiment_Polarity'].describe()
# Out:
# count    37427.000000
# mean         0.182171
# std          0.351318
# min         -1.000000
# 25%          0.000000
# 50%          0.150000
# 75%          0.400000
# max          1.000000
# Name: Sentiment_Polarity, dtype: float64

# %% [markdown]
# # **5.Sentiment_Subjectivity**

# %%
#getting first 5 records of sentiment subjectivity
df_u_reviews['Sentiment_Subjectivity'].head()
# Out:
# 0    0.533333
# 1    0.288462
# 3    0.875000
# 4    0.300000
# 5    0.300000
# Name: Sentiment_Subjectivity, dtype: float64

# %%
#getting number of unique vaues of Sentiment_subjectivity
df_u_reviews['Sentiment_Subjectivity'].nunique()
# Out:
# 4474

# %%
#getting unique vaues of Sentiment_subjectivity
df_u_reviews['Sentiment_Subjectivity'].unique()
# Out:
# array([0.53333333, 0.28846154, 0.875     , ..., 0.51145833, 0.7172619 ,
#        0.2594697 ])

# %%
#getting value counts
df_u_reviews['Sentiment_Subjectivity'].value_counts()
# Out:
# 0.000000    4411
# 1.000000    1749
# 0.500000    1647
# 0.600000    1166
# 0.750000    1140
#             ...
# 0.616909       1
# 0.234848       1
# 0.154762       1
# 0.591146       1
# 0.259470       1
# Name: Sentiment_Subjectivity, Length: 4474, dtype: int64

# %%
#getting statistics of sentiment subjectivity
df_u_reviews['Sentiment_Subjectivity'].describe()
# Out:
# count    37427.000000
# mean         0.492770
# std          0.259904
# min          0.000000
# 25%          0.357143
# 50%          0.514286
# 75%          0.650000
# max          1.000000
# Name: Sentiment_Subjectivity, dtype: float64

# %% [markdown]
# # **Percentage of Review Sentiments**

# %%
#getting list of sentiment value counts
counts = list(df_u_reviews['Sentiment'].value_counts())
counts
# Out:
# [23998, 8271, 5158]

# %%
#getting piechart of percentage reviews sentiment
import matplotlib
counts = list(df_u_reviews['Sentiment'].value_counts())
labels = 'Positive Reviews', 'Negative Reviews','Neutral Reviews'
matplotlib.rcParams['font.size'] = 25
matplotlib.rcParams['figure.figsize'] = (12, 17)
plt.pie(counts, labels=labels, explode=[0.01, 0.05, 0.05], shadow=True, autopct="%.2f%%")
plt.title('Percentage of Review Sentiments', fontsize=20)
plt.axis('off')
plt.legend(bbox_to_anchor=(0.9, 0, 0.5, 1))
plt.show()

# %% [markdown]
# # **Insights:**
#
# * Positive reviews are 64.12%
# * Negative reviews are 22.10%
# * Neutral reviews are 13.78%

# %% [markdown]
# # **Apps with the highest number of positive reviews`**

# %%
#getting positve reviews
pos_ur_df=df_u_reviews[df_u_reviews['Sentiment']=='Positive']
pos_ur_df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64217  Housing-Real Estate & Property
# 64221  Housing-Real Estate & Property
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
# Top 15 positive reviews apps
pos_ur_df.groupby('App')['Sentiment'].value_counts().nlargest(15).plot.barh(figsize=(10,8),color='green').invert_yaxis()
plt.title("Top 15 positive review apps")
plt.xlabel('Total number of positive reviews')
plt.yticks(rotation=0)
plt.legend()

# %% [markdown]
# # **Apps** with the highest number of negative reviews

# %%
#getting to 15 negative reviews apps
neg_ur_df=df_u_reviews[df_u_reviews['Sentiment']=='Negative']
neg_ur_df
# Out:
#                                   App  \
# 32              10 Best Foods for You
# 43              10 Best Foods for You
# 68              10 Best Foods for You
# 85              10 Best Foods for You
# 95              10 Best Foods for You
# ...                               ...
# 64215  Housing-Real Estate & Property
# 64216  Housing-Real Estate & Property
# 64220  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 32                    No recipe book Unable recipe book.  Negative
# 43     Waste time It needs internet time n ask calls ...  Negative
# 68                               Faltu plz waste ur time  Negative
# 85                                     Crap Doesn't work  Negative
# 95     Boring. I thought actually just texts that's i...  Negative
# ...                                                  ...       ...
# ...

# %%
#getting bar plot of top 15 negative reviews apps
neg_ur_df.groupby('App')['Sentiment'].value_counts().nlargest(15).plot.bar(figsize=(16,4),color='red')
plt.title("Top 15 negative review apps")
plt.xlabel('Total number of negative reviews')
plt.legend()

# %%
#getting neutral reviews records
neut_ur_df=df_u_reviews[df_u_reviews['Sentiment']=='Neutral']
neut_ur_df
# Out:
#                                   App  \
# 8               10 Best Foods for You
# 9               10 Best Foods for You
# 22              10 Best Foods for You
# 25              10 Best Foods for You
# 29              10 Best Foods for You
# ...                               ...
# 64189  Hotwire Hotel & Car Rental App
# 64194  Hotwire Hotel & Car Rental App
# 64200  Housing-Real Estate & Property
# 64205  Housing-Real Estate & Property
# 64218  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 8                                   Looking forward app,   Neutral
# 9                  It helpful site ! It help foods get !   Neutral
# 22                                            God health   Neutral
# 25                     I found lot wealth form health...   Neutral
# 29                                           On test....   Neutral
# ...                                                  ...       ...
# ...

# %%
#getting top 15 neutral reviews record of apps
neut_ur_df.groupby('App')['Sentiment'].value_counts().nlargest(15).plot.barh(figsize=(15,8),color='yellow').invert_yaxis()
plt.title("Top 15 neutral review apps")
plt.xlabel('Total number of neutral reviews')
plt.legend()

# %%
#merged dataframe sentiment subjectivity value counts
merged_df.Sentiment_Subjectivity.value_counts()
# Out:
# 0.000000    4139
# 1.000000    1653
# 0.500000    1579
# 0.600000    1133
# 0.750000    1095
#             ...
# 0.508052       1
# 0.454167       1
# 0.417316       1
# 0.765000       1
# 0.545714       1
# Name: Sentiment_Subjectivity, Length: 4382, dtype: int64

# %%
#to get distribution plot of merged dataframe sentiment subjectivity
plt.figure(figsize=(18,9))
plt.xlabel("Subjectivity")
plt.title("Distribution of Subjectivity")
plt.hist(merged_df[merged_df['Sentiment_Subjectivity'].notnull()]['Sentiment_Subjectivity'])
plt.show()

# %% [markdown]
# It can be seen that maximum number of sentiment subjectivity lies between 0.4 to 0.7. From this we can conclude that maximum number of users give reviews to the applications, according to their experience while using apps.

# %%
# scatterplot of sentiment polarity and sentiment subjectivity
plt.figure(figsize=(15, 10))
sns.scatterplot(df_u_reviews['Sentiment_Subjectivity'], df_u_reviews['Sentiment_Polarity'],
                hue = df_u_reviews['Sentiment'], edgecolor='white', palette="inferno")
plt.title("Google Play Store Reviews Sentiment Analysis", fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# From the above scatter plot it can be concluded that sentiment subjectivity is not always proportional to sentiment polarity but in maximum number of cases, shows a proportional behavior, when variance is too high or low

# %% [markdown]
# # **Does Last Update date has an effects on rating?**

# %%
print(df['Last Updated'].head())
#fetch update year from date
df["Update year"] = df["Last Updated"].apply(lambda x: x.strftime('%Y')).astype('int64')
# Out:
# 0   2018-01-07
# 1   2018-01-15
# 2   2018-08-01
# 3   2018-06-08
# 4   2018-06-20
# Name: Last Updated, dtype: datetime64[ns]

# %%
#to plot linear regressio plot between year and rating
fig, ax = plt.subplots(figsize=(12,6)) # to control size of plot
sns.regplot(x="Update year", y="Rating", data=df)
plt.title("Update Year VS Rating")
# Out:
# Text(0.5, 1.0, 'Update Year VS Rating')

# %% [markdown]
# From above plot we can conclude that latest update has maximum ratings as it contains updated features.

# %% [markdown]
# # **Conclusion :**From above analysys we conclude that the key factors responsible for app engagement and success are as described below.

# %% [markdown]
# **1.Rating**
#
# Most of the apps have rating in between 4 and 5.
#
# Most numbers of apps are rated at 4.3
#
# Categories of apps have more than 4 average rating.item
#
# **2.Size**
#
# Maximum number of applications present in the dataset are of small size.
#
# **3.Installs**
#
# Majority of the apps come into these three categories, Family, Game, and Tools.
#
# Maximum number of apps present in google play store come under Family, Game and tools but as per the installation and requirement in the market plot, scenario is not the same. Maximum installed apps comes under Game, Communication, Productivity and Social.
#
# Subway Surfers, Facebook, Messenger and Google Drive are the most installed apps.
#
# **4.Type(Free/Paid)**
#
# About 92% apps are free and 8% apps are of paid type.
#
# The category ‘Family’ has the highest number of paid apps.
#
# Free apps are installed more than paid apps.
#
# The app “I’m Rich — Trump Edition” from the category ‘Lifestyle’ is the most costly app priced at $400
#
# **5.Content Rating**
#
# Content having Everyone only has most installs, while unrated and Adults only 18+ have less installs.
#
# **6.Reviews**
#
# Number of installs is positively correlated with reviews with correlation 0.63.
#
# **7.Sentiment**
#
# Most of the reviews are of Positive Sentiment, while Negative and Neutral have low number of reviews.
#
# **8.Sentiment Polarity / Sentiment Subjectivity**
#
# Collection of reviews shows a wide range of subjectivity and most of the reviews fall in [-0.50,0.75] polarity scale implying that the extremely negative or positive sentiments are significantly low. Most of the reviews show a mid-range of negative and positive sentiments.
#
# Sentiment subjectivity is not always proportional to sentiment polarity but in maximum number of case, shows a proportional behavior, when variance is too high or low.
#
# Sentiment Polarity is not highly correlated with Sentiment Subjectivity.

# %% [markdown]
# * Overall sentiment count of USER REVIEWS  dataset as described below.
#
#  Positive sentiment count is 64%
#
#  Negative 22% and Neutral 13%.
#
# * The median size of all apps in the play store is 12 MB.
#
# * The apps whose size varies with device has the highest number average app installs.
#
# * Helix Jump has the highest number of positive reviews and Angry Birds Classic has the highest number of negative reviews.
#
# * Percentage of free apps = ~92%
#
# * Most of the apps are Free, so focusing on free app is more important.
# Focusing more on content available for Everyone will increase the chances of getting the highest installs.
#
# * They need to focus on updating their apps regularly, so that it will attract more users.
#
# * They need to keep in mind that the sentiments of the user keep varying as they keep using the app, so they should focus more on users needs and features.
#
#
# * Family, Game and Tools are top three categories having 1906, 926 and 829 app count.
#
# * apps with Game Category has the highest average app installs.
